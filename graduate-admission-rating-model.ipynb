# %% [markdown]
#  # Graduate Admission Rating Model

# %% [markdown]
# **importing required libraries**

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error
import numpy as np

# %% [markdown]
# **reading/uploading the dataset**

# %%
dataset=pd.read_csv('/kaggle/input/admissions/Admission.csv')

# %% [markdown]
# **What are the number of rows & columns?**

# %%
dataset.shape
# Out:
# (1000, 8)

# %% [markdown]
# We have a dataset spanning 1000 rows and 8 columns

# %% [markdown]
# **Printing the first 10 rows**

# %%
dataset.head(10)
# Out:
#    GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  Research  \
# 0      337.0        118.0                4.0  4.5   4.5  9.65       1.0
# 1      324.0        107.0                4.0  4.0   4.5  8.87       1.0
# 2      316.0        104.0                3.0  3.0   3.5  8.00       1.0
# 3      322.0        110.0                3.0  3.5   2.5  8.67       1.0
# 4      314.0        103.0                2.0  2.0   3.0  8.21       0.0
# 5      330.0        115.0                5.0  4.5   3.0  9.34       1.0
# 6      321.0        109.0                3.0  3.0   4.0  8.20       1.0
# 7      308.0        101.0                2.0  3.0   4.0  7.90       0.0
# 8      302.0        102.0                1.0  2.0   1.5  8.00       0.0
# 9      323.0        108.0                3.0  3.5   3.0  8.60       0.0
#
#    Chance of Admit
# 0             0.92
# 1             0.76
# 2             0.72
# 3             0.80
# 4             0.65
# 5             0.90
# 6             0.75
# 7             0.68
# 8             0.50
# 9             0.45

# %% [markdown]
# **Printing the last 10 rows**

# %%
dataset.tail(10)
# Out:
#      GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  Research  \
# 990      312.0        104.0                2.0  2.4   2.9  8.13       1.0
# 991      310.0        106.0                2.0  2.3   3.9  8.11       1.0
# 992      307.0        102.0                2.0  1.8   2.8  8.74       1.0
# 993      318.0        107.0                3.0  4.5   4.9  8.52       1.0
# 994      305.0         99.0                2.0  1.9   1.9  8.09      -0.0
# 995      314.0        109.0                1.0  2.5   4.1  8.78       1.0
# 996      322.0        102.0                3.0  3.5   2.7  8.17       1.0
# 997      324.0        109.0                3.0  3.2   3.1  8.51       1.0
# 998      298.0         95.0                2.0  3.1   2.5  8.11      -0.0
# 999      333.0        114.0                5.0  4.2   3.9  9.23       1.0
#
#      Chance of Admit
# 990         0.539438
# 991         0.666709
# 992         0.732535
# 993         0.770040
# 994         0.592842
# 995         0.788787
# 996         0.683076
# 997         0.725821
# 998         0.560290
# 999         0.831325

# %% [markdown]
# **Checking if any of the columns have empty/null values**

# %%
dataset.isnull().any()
# Out:
# GRE Score            False
# TOEFL Score          False
# University Rating    False
# SOP                  False
# LOR                  False
# CGPA                 False
# Research             False
# Chance of Admit      False
# dtype: bool

# %% [markdown]
# This tells us that none of the columns have empty cells

# %% [markdown]
# **Stripping any leading or trailing whitespaces in a column name**

# %%
dataset.columns=dataset.columns.str.strip()

# %% [markdown]
# Column Heading 'LOR' had either trailing or leading whitespaces.

# %% [markdown]
# **Getting range of values used to rating in each columns**

# %%
print("GRE Score range: ",dataset['GRE Score'].min(),"-",dataset['GRE Score'].max())
print("TOEFL Score range: ",dataset['TOEFL Score'].min(),"-",dataset['TOEFL Score'].max())
print("University Rating range: ",dataset['University Rating'].min(),"-",dataset['University Rating'].max())
print("SOP range: ",dataset['SOP'].min(),"-",dataset['SOP'].max())
print("LOR range: ",dataset['LOR'].min(),"-",dataset['LOR'].max())
print("CGPA range: ",dataset['CGPA'].min(),"-",dataset['CGPA'].max())
print("Research range: ",dataset['Research'].min(),"-",dataset['Research'].max())
print("Chances of Admit range: ",dataset['Chance of Admit'].min(),"-",dataset['Chance of Admit'].max())
# Out:
# GRE Score range:  290.0 - 340.0
# TOEFL Score range:  92.0 - 120.0
# University Rating range:  1.0 - 5.0
# SOP range:  1.0 - 5.0
# LOR range:  1.0 - 5.0
# CGPA range:  6.8 - 9.92
# Research range:  -0.0 - 1.0
# Chances of Admit range:  0.34 - 0.97

# %% [markdown]
# **Getting some more statistical insights**

# %%
dataset.describe()
# Out:
#          GRE Score  TOEFL Score  University Rating          SOP          LOR  \
# count  1000.000000  1000.000000        1000.000000  1000.000000  1000.000000
# mean    316.432000   107.227000           3.095000     3.344800     3.475500
# std      11.324028     6.132461           1.166763     1.022712     0.956151
# min     290.000000    92.000000           1.000000     1.000000     1.000000
# 25%     308.000000   103.000000           2.000000     2.500000     2.900000
# 50%     317.000000   107.000000           3.000000     3.500000     3.500000
# 75%     325.000000   112.000000           4.000000     4.000000     4.200000
# max     340.000000   120.000000           5.000000     5.000000     5.000000
#
#               CGPA     Research  Chance of Admit
# count  1000.000000  1000.000000      1000.000000
# mean      8.570980     0.556000         0.720568
# std       0.609056     0.497103         0.143180
# min       6.800000    -0.000000         0.340000
# 25%       8.127500     0.000000         0.629591
# 50%       8.560000     1.000000         0.724833
# 75%       9.020000     1.000000         0.820000
# max       9.920000     1.000000         0.970000

# %% [markdown]
# **Splitting the column we need to predict**

# %%
x=dataset.drop('Chance of Admit',axis=1)
y=dataset['Chance of Admit']

# %% [markdown]
# **Separating training and testing sets**

# %%
x_train, x_test, y_train, y_test=train_test_split(x,y, test_size=0.18, random_state=3)

# %% [markdown]
# **Using GradientBoostingClassifier**

# %%
model=model = RandomForestRegressor(n_estimators=100, max_depth=5)

# %% [markdown]
# model chosen

# %% [markdown]
# **Fitting the model on my dataset**

# %%
model.fit(x_train,y_train)
# Out:
# RandomForestRegressor(max_depth=5)

# %% [markdown]
# Model has been trained on our dataset.

# %% [markdown]
# **Predicting for arbitrary values**

# %%
p=model.predict([[329,110,5,4.2,4,8.78,1.00]])
p[0]
# Out:
# /opt/conda/lib/python3.10/site-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# 0.8198670039137983

# %% [markdown]
# * **Candidate Details given**
# * GRE Score: 329
# * TOEFL Score: 110
# * SOP: 4.2
# * LOR: 4
# * CGPA: 8.78
# * Research: 1.00
# ***According to our model this candidate has 81.98%~82% chance of getting admitted.**

# %% [markdown]
# **Assessing performance using rmse**

# %%
y_test_pred = model.predict(x_test)
mse = mean_squared_error(y_test, y_test_pred)
rmse = np.sqrt(mse)
print(f"Root Mean Squared Error (RMSE): {rmse:.2f}")
# Out:
# Root Mean Squared Error (RMSE): 0.07
